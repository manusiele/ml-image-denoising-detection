# %% [markdown]
# # CNN-Based Object Detection
# Train and evaluate object detection on original vs. denoised images

# %%
import sys
sys.path.append('../src')

import torch
import torchvision
from detection.model import ObjectDetector
from evaluation.metrics import DetectionMetrics

# %matplotlib inline

# %% [markdown]
# ## Initialize Model

# %%
detector = ObjectDetector(num_classes=21, pretrained=True)
print(f"Device: {detector.device}")

# %% [markdown]
# ## Train on Original Images

# %%
# TODO: Prepare data loaders and train

# %% [markdown]
# ## Train on Denoised Images

# %%
# TODO: Train on enhanced images

# %% [markdown]
# ## Compare mAP Results

# %%
# TODO: Calculate and compare mAP scores
