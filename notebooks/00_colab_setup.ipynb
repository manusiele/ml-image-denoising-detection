# %% [markdown]
# # Google Colab Setup - Pascal VOC Object Detection
#
# Run this notebook on Google Colab to use cloud storage and free GPU!
#
# **Steps:**
# 1. Upload this notebook to Google Colab
# 2. Run all cells
# 3. Dataset stays in Colab's cloud storage
# 4. No local storage needed!

# %% [markdown]
# ## 1. Mount Google Drive (Optional - for saving results)

# %%
from google.colab import drive
drive.mount('/content/drive')
print("✓ Google Drive mounted")

# %% [markdown]
# ## 2. Install Dependencies

# %%
# !pip install -q kaggle python-dotenv scikit-image
print("✓ Dependencies installed")

# %% [markdown]
# ## 3. Setup Kaggle API

# %%
import os

# Set your Kaggle API token
os.environ['KAGGLE_API_TOKEN'] = 'KGAT_10093738af41f73df7931af73c845bbd'

# Create kaggle directory
# !mkdir -p ~/.kaggle

print("✓ Kaggle API configured")

# %% [markdown]
# ## 4. Download Pascal VOC Dataset to Colab Storage

# %%
# Download to Colab's temporary storage
import os
os.makedirs('/content/data', exist_ok=True)

# !kaggle datasets download -d huanghanchina/pascal-voc-2012 -p /content/data --force

# Find the downloaded zip file
import glob
zip_files = glob.glob('/content/data/*.zip')
if zip_files:
    zip_file = zip_files[0]
    print(f"Found zip file: {zip_file}")
    # !unzip -q {zip_file} -d /content/data/pascal-voc
    # !rm {zip_file}
    print("Dataset extracted to /content/data/pascal-voc")
else:
    print("Error: No zip file found")

# %% [markdown]
# ## 5. Verify Dataset

# %%
import os
from pathlib import Path

data_dir = Path('/content/data/pascal-voc')
print(f"Dataset directory exists: {data_dir.exists()}")

# List contents
if data_dir.exists():
    print("\nDataset structure:")
    for item in data_dir.rglob('*'):
        if item.is_dir():
            print(f"  📁 {item.relative_to(data_dir)}")

# %% [markdown]
# ## 6. Load Sample Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Find image files
image_dir = Path('/content/data/pascal-voc')
image_files = list(image_dir.rglob('*.jpg'))[:6]

# Display images
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for idx, img_path in enumerate(image_files):
    img = cv2.imread(str(img_path))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    axes[idx].imshow(img)
    axes[idx].set_title(img_path.name)
    axes[idx].axis('off')

plt.tight_layout()
plt.show()

print(f"✓ Loaded {len(image_files)} sample images")

# %% [markdown]
# ## 7. Clone Your GitHub Repository

# %%
# !git clone https://github.com/manusiele/ml-image-denoising-detection.git
# %cd ml-image-denoising-detection
print("✓ Repository cloned")

# %% [markdown]
# ## 8. Ready to Work!
#
# Now you can:
# - Run your denoising algorithms
# - Train object detection models
# - Evaluate with PSNR/SSIM and mAP
#
# All data is in Colab's cloud storage - no local storage used!
