# %% [markdown]
# # Image Denoising and Enhancement
# Apply various denoising techniques and evaluate with PSNR/SSIM

# %%
import sys
sys.path.append('../src')

import cv2
import numpy as np
import matplotlib.pyplot as plt
from preprocessing.denoising import ImageDenoiser
from evaluation.metrics import ImageQualityMetrics

# %matplotlib inline

# %% [markdown]
# ## Load Sample Image from Kaggle API

# %%
from data.kaggle_loader import KaggleDataLoader

# Load image directly from Kaggle
loader = KaggleDataLoader('huanghanchina/pascal-voc-2012')
filename, image = next(loader.stream_dataset_files('*.jpg', max_files=1))

print(f"Loaded: {filename}")
print(f"Shape: {image.shape}")

plt.figure(figsize=(10, 6))
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Apply Denoising Techniques

# %%
denoiser = ImageDenoiser()

# Apply different techniques
# gaussian = denoiser.gaussian_blur(image)
# bilateral = denoiser.bilateral_filter(image)
# nlm = denoiser.non_local_means(image)

# %% [markdown]
# ## Evaluate Quality (PSNR/SSIM)

# %%
metrics = ImageQualityMetrics()

# Calculate metrics
# results = metrics.evaluate_image_pair(original, denoised)
# print(f"PSNR: {results['psnr']:.2f} dB")
# print(f"SSIM: {results['ssim']:.4f}")
